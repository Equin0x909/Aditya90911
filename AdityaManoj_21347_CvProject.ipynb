# %% [markdown]
# <a href="https://colab.research.google.com/github/Equin0x909/Aditya90911/blob/main/AdityaManoj_21347_CvProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setting up PyTorch and YOLOv5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %% [markdown]
# # Unzipping the dataset

# %%
# !unzip -q ../thermal_imaging_dataset.zip -d ../

# %% [markdown]
# ## Training the pre-trained YOLOv5 model on the custom thermal dataset

# %%
#basic parameters:
# - image size (img): image size of the dataset is 640 x 512, 640 passed
# - batch size (batch): 16 by default, 16 passed
# - epochs (epochs): number of epochs, 30 passed
# - dataset (data): dataset in .yaml file format, custom thermal image dataset passed
# - pre-trained YOLOv5 model (weights): YOLOv5 model version, YOLOv5s (small version) passed
# !python train.py --img 640 --batch 16 --epochs 30 --data thermal_imaging_dataset.yaml --weights yolov5s.pt
# Out:
# 2023-12-07 18:05:51.721761: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-07 18:05:51.721818: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-07 18:05:51.721858: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Test: Inferences

# %%
# test the trained model (best.pt) on a thermal imaging video,
# parameters:
# - trained models (weights): model trained in the previous step, best.pt passed
# - image size (img): frame size of the thermal video is 640 x 512, 640 passed
# - confidence (conf): confidence threshold, only the inferences higher than this value will be shown, 0.35 passed
# - video file (source): thermal imaging video, thermal imaging video.mp4 passed
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.35 --source ../thermal_imaging_video.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (3445/8442) /content/thermal_imaging_video.mp4: 512x640 11 cars, 4 persons, 6.0ms
# video 1/1 (3446/8442) /content/thermal_imaging_video.mp4: 512x640 11 cars, 4 persons, 6.0ms
# video 1/1 (3447/8442) /content/thermal_imaging_video.mp4: 512x640 7 cars, 6.7ms
# video 1/1 (3448/8442) /content/thermal_imaging_video.mp4: 512x640 7 cars, 7.1ms
# video 1/1 (3449/8442) /content/thermal_imaging_video.mp4: 512x640 9 cars, 6.0ms
# video 1/1 (3450/8442) /content/thermal_imaging_video.mp4: 512x640 9 cars, 6.0ms
# video 1/1 (3451/8442) /content/thermal_imaging_video.mp4: 512x640 7 cars, 7.3ms
# video 1/1 (3452/8442) /content/thermal_imaging_video.mp4: 512x640 7 cars, 6.2ms
# video 1/1 (3453/8442) /content/thermal_imaging_video.mp4: 512x640 11 cars, 6.9ms
# video 1/1 (3454/8442) /content/thermal_imaging_video.mp4: 512x640 11 cars, 6.0ms
# video 1/1 (3455/8442) /content/thermal_imaging_video.mp4: 512x640 9 cars, 7.1ms
# ...
